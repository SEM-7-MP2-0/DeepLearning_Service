# %%
from mtcnn import MTCNN
import cv2

# %%
img = cv2.cvtColor(cv2.imread("../output/0aa9ee84-8d60-4939-81d7-85e900a64f49.jpg"), cv2.COLOR_BGR2RGB)

# %%
detector = MTCNN()

# %%
detections= detector.detect_faces(img)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 803ms/step
# 1/1 [==============================] - 0s 351ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 143/143 [==============================] - 2s 10ms/step
# 18/18 [==============================] - 1s 38ms/step

# %%
import matplotlib.pyplot as plt

img_with_dets = img.copy()
min_conf = 0.9
person_count = 0
for det in detections:
    if det['confidence'] >= min_conf:
        person_count += 1
        x, y, width, height = det['box']
        keypoints = det['keypoints']
        cv2.rectangle(img_with_dets, (x,y), (x+width,y+height), (0,155,255), 2)
        cv2.circle(img_with_dets, (keypoints['left_eye']), 2, (0,155,255), 2)
        cv2.circle(img_with_dets, (keypoints['right_eye']), 2, (0,155,255), 2)
        cv2.circle(img_with_dets, (keypoints['nose']), 2, (0,155,255), 2)
        cv2.circle(img_with_dets, (keypoints['mouth_left']), 2, (0,155,255), 2)
        cv2.circle(img_with_dets, (keypoints['mouth_right']), 2, (0,155,255), 2)
plt.figure(figsize = (10,10))
plt.imshow(img_with_dets)
plt.axis('off')
# Out:
# (-0.5, 4031.5, 3023.5, -0.5)

# %%
person_count
# Out:
# 63
